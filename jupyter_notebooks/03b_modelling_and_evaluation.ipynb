# %% [markdown]
# # **Modelling and Evaluation B**

# %% [markdown]
# ## Objectives
#
# * Answer Business requirement 2:
#     * The client wants to be able to know from the MRI brain scan if a patient has a tumor or not.
#
# ## Inputs
#
# * input/train
# * input/test
# * input/validation
# * image shape embeddings
#
# ## Outputs
#
# * Images distribution plot in train, validation, and test set
# * Image augmentation
# * Class indices to change prediction inference in labels
# * Machine learning model creation and training
# * Saved model
# * Learning curve plot for model performance
# * Model evaluation on pickle file
# * Prediction on the random image file.
#
# ## Additional Comments
#
# * Because the previous model didn't give a satisfactory results, we decided to optimize the model by optimizing the hyperparameters

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/home/tom/codeinstitute/brain-tumor-detect/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
working_dir = os.getcwd()
working_dir
# Out:
# '/home/tom/codeinstitute/brain-tumor-detect'

# %% [markdown]
# # Import regular packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

# %% [markdown]
# ---

# %% [markdown]
# # Set input directories

# %% [markdown]
# Set train, validation and test paths

# %%
input_dir = 'input'
train_path = os.path.join(input_dir, 'train')
test_path = os.path.join(input_dir, 'test')
validation_path = os.path.join(input_dir, 'validation')

# %% [markdown]
# # Set ouput directory

# %%
version = 'v2'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(working_dir) and version in os.listdir(os.path.join(working_dir, 'outputs')):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ---

# %% [markdown]
# # Set lables

# %%
labels = os.listdir(train_path)
print(f'Project lables: {labels}')
# Out:
# Project lables: ['mri-tumor', 'mri-non-tumor']

# %% [markdown]
# # Load image shape

# %% [markdown]
# ## Import saved image shape embedding

# %%
import joblib
image_shape = joblib.load(filename=f'outputs/{version}/image_shape.pkl')
image_shape
# Out:
# (96, 96, 3)

# %% [markdown]
# # Number of images in train, test and validation data sets and their respective data balance

# %%
df_freq = pd.DataFrame([])
for folder in ['train', 'validation', 'test']:
    for label in labels:
        df_freq = df_freq.append(
            pd.Series(data={'Set': folder,
                            'Label': label,
                            'Frequency': int(len(os.listdir(os.path.join(input_dir, folder, label))))}
                      ),
            ignore_index=True
        )

        print(
            f"* {folder} - {label}: {len(os.listdir(os.path.join(input_dir, folder, label)))} images")

print("\n")
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))
sns.barplot(data=df_freq, x='Set', y='Frequency', hue='Label')
plt.savefig(f'{file_path}/labels_distribution.png',
            bbox_inches='tight', dpi=150)
plt.show()
# Out:
# * train - mri-tumor: 1178 images
# * train - mri-non-tumor: 1455 images
# * validation - mri-tumor: 169 images
# * validation - mri-non-tumor: 209 images
# * test - mri-tumor: 336 images
# * test - mri-non-tumor: 415 images

# %% [markdown]
# From the diagram we can observe that the datasets are imbalanced. We will procede with data augmentation, and, if necessary, with over sampling the mri-tumor datasets.

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Image Data Augmentation

# %% [markdown]
# ---

# %% [markdown]
# ## Import ImageDataGenerator from tensorflow library

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# We will then setup the pipeline for the image data generator

# %%
from keras.preprocessing.image import ImageDataGenerator
augmentation_data = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[0.5, 1.5],
    shear_range = 15,
    fill_mode='nearest',
    rescale=1.0/255.0,
)

# %% [markdown]
# ## Augmentation of the training image dataset

# %%
batch_size = 20 
train_set = augmentation_data.flow_from_directory(train_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     shuffle=True
                                                     )

train_set.class_indices
# Out:
# Found 2633 images belonging to 2 classes.
# {'mri-non-tumor': 0, 'mri-tumor': 1}

# %% [markdown]
# ## Augmentation of the validation image dataset

# %%
validation_set = augmentation_data.flow_from_directory(validation_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     shuffle=True
                                                     )

validation_set.class_indices
# Out:
# Found 378 images belonging to 2 classes.
# {'mri-non-tumor': 0, 'mri-tumor': 1}

# %% [markdown]
# ## Augmentation of the test image dataset

# %%
test_set = augmentation_data.flow_from_directory(test_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     shuffle=True
                                                     )

test_set.class_indices
# Out:
# Found 751 images belonging to 2 classes.
# {'mri-non-tumor': 0, 'mri-tumor': 1}

# %% [markdown]
# ---

# %% [markdown]
# ## Plot augmented training images

# %%
for i in range(5):
    img, label = train_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)

# %% [markdown]
# ## Plot augmented validation images

# %%
for i in range(5):
    img, label = validation_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)

# %% [markdown]
# ## Plot augmented test images

# %%
for i in range(5):
    img, label = test_set.next()
    print(img.shape) 
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)
# (20, 96, 96, 3)

# %% [markdown]
# # Save class indices

# %%
joblib.dump(value=train_set.class_indices,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v2/class_indices.pkl']

# %% [markdown]
# # Model Creation

# %% [markdown]
# Install Keras Tuner

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in ./venv/lib/python3.8/site-packages (1.4.6)
# Requirement already satisfied: keras in ./venv/lib/python3.8/site-packages (from keras-tuner) (2.6.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.8/site-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in ./venv/lib/python3.8/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests->keras-tuner) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests->keras-tuner) (2023.11.17)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Import model packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %% [markdown]
# ## Building Model Function

# %%
def build_model(hp):
    model = Sequential()

    # Convolutional layers
    for i in range(hp.Int('num_conv_layers', 1, 3)):  # Number of convolutional layers
        model.add(Conv2D(filters=hp.Choice(f'filters_{i}', [32, 64, 128]), 
                         kernel_size=(3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    # Dense layer
    model.add(Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), 
                    activation='relu'))

    # Dropout layer
    model.add(Dropout(rate=hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    model.compile(
        optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ## Hyperparameter Tuning with Keras Tuner

# %% [markdown]
# Import Keras Tuner function

# %%
from tensorflow import keras
from keras_tuner import RandomSearch

# %%
# Define the tuner Random Search
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='mri_tuning'
)

# %% [markdown]
# Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# %% [markdown]
# Implementing Class Weights from Keras for the balancing of the dataset

# %%
from sklearn.utils import class_weight
# Calculate class weights
class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(train_set.classes),
                                                  train_set.classes)

class_weights_dict = {i:class_weights[i] for i in range(len(class_weights))}

# %% [markdown]
# Solve a memory problem
# * 2024-01-03 22:35:11.587342: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 398114816 exceeds 10% of free system memory.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# Search for the best hyperparameters
tuner.search(train_set,
             epochs=25,
             steps_per_epoch=len(train_set.classes) // batch_size,
             validation_data=validation_set,
             class_weight=class_weights_dict,
             callbacks=[early_stop],
             verbose=2)
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is {best_hps.get('units')} and the optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.")
# Out:
# Epoch 1/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Search for the best hyperparameters
# ----> 2 tuner.search(train_set,
#       3              epochs=25,
#       4              steps_per_epoch=len(train_set.classes) // batch_size,
#       5              validation_data=validation_set,
#       6              class_weight=class_weights_dict,
#       7              callbacks=[early_stop],
#       8              verbose=2)
#       9 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#      10 print(f"The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is {best_hps.get('units')} and the optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.")
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/keras/engine/training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1177 with tf.profiler.experimental.Trace(
#    1178     'train',
#    1179     epoch_num=epoch,
#    1180     step_num=step,
#    1181     batch_size=batch_size,
#    1182     _r=1):
#    1183   callbacks.on_train_batch_begin(step)
# -> 1184   tmp_logs = self.train_function(iterator)
#    1185   if data_handler.should_sync:
#    1186     context.async_wait()
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/def_function.py:885, in Function.__call__(self, *args, **kwds)
#     882 compiler = "xla" if self._jit_compile else "nonXla"
#     884 with OptionalXlaContext(self._jit_compile):
# --> 885   result = self._call(*args, **kwds)
#     887 new_tracing_count = self.experimental_get_tracing_count()
#     888 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/def_function.py:917, in Function._call(self, *args, **kwds)
#     914   self._lock.release()
#     915   # In this case we have created variables on the first call, so we run the
#     916   # defunned version which is guaranteed to never create variables.
# --> 917   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918 elif self._stateful_fn is not None:
#     919   # Release the lock early so that multiple threads can perform the call
#     920   # in parallel.
#     921   self._lock.release()
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/function.py:3039, in Function.__call__(self, *args, **kwargs)
#    3036 with self._lock:
#    3037   (graph_function,
#    3038    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039 return graph_function._call_flat(
#    3040     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/function.py:1963, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1959 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1960 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1961     and executing_eagerly):
#    1962   # No tape is watching; skip to running the function.
# -> 1963   return self._build_call_outputs(self._inference_function.call(
#    1964       ctx, args, cancellation_manager=cancellation_manager))
#    1965 forward_backward = self._select_forward_and_backward_functions(
#    1966     args,
#    1967     possible_gradient_type,
#    1968     executing_eagerly)
#    1969 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File ~/codeinstitute/brain-tumor-detect/venv/lib64/python3.8/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Create Model with the best hyperparameters

# %%
model = tuner.hypermodel.build(best_hps)

# %% [markdown]
# ## Model Summary

# %%
build_model().summary()
# Out:
# 2024-01-02 11:43:40.990755: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 238, 238, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 119, 119, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 117, 117, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 58, 58, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               12845184
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 12,938,561
# Trainable params: 12,938,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit model for training

# %%
model = build_model()
model.fit(train_set,
          epochs=25,
          steps_per_epoch=len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# 2024-01-02 11:47:56.511297: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 65/65 [==============================] - 629s 10s/step - loss: 0.6009 - accuracy: 0.6919 - val_loss: 0.5291 - val_accuracy: 0.7540
# Epoch 2/25
# 65/65 [==============================] - 502s 8s/step - loss: 0.5206 - accuracy: 0.7428 - val_loss: 0.4968 - val_accuracy: 0.7407
# Epoch 3/25
# 65/65 [==============================] - 717s 11s/step - loss: 0.4925 - accuracy: 0.7709 - val_loss: 0.5112 - val_accuracy: 0.7593
# Epoch 4/25
# 65/65 [==============================] - 578s 9s/step - loss: 0.5016 - accuracy: 0.7690 - val_loss: 0.4635 - val_accuracy: 0.7989
# Epoch 5/25
# 65/65 [==============================] - 505s 8s/step - loss: 0.4983 - accuracy: 0.7671 - val_loss: 0.4851 - val_accuracy: 0.7646
# Epoch 6/25
# 65/65 [==============================] - 560s 9s/step - loss: 0.4855 - accuracy: 0.7667 - val_loss: 0.4617 - val_accuracy: 0.7884
# Epoch 7/25
# 65/65 [==============================] - 571s 9s/step - loss: 0.4825 - accuracy: 0.7755 - val_loss: 0.4702 - val_accuracy: 0.7619
# Epoch 8/25
# 65/65 [==============================] - 537s 8s/step - loss: 0.4786 - accuracy: 0.7744 - val_loss: 0.4580 - val_accuracy: 0.8042
# Epoch 9/25
# 65/65 [==============================] - 519s 8s/step - loss: 0.4832 - accuracy: 0.7771 - val_loss: 0.4892 - val_accuracy: 0.7672
# Epoch 10/25
# 65/65 [==============================] - 660s 10s/step - loss: 0.4677 - accuracy: 0.7894 - val_loss: 0.4663 - val_accuracy: 0.7937
# Epoch 11/25
# 65/65 [==============================] - 672s 10s/step - loss: 0.4674 - accuracy: 0.7728 - val_loss: 0.4575 - val_accuracy: 0.7989
# Epoch 12/25
# 65/65 [==============================] - 622s 10s/step - loss: 0.4638 - accuracy: 0.7809 - val_loss: 0.5036 - val_accuracy: 0.7698
# Epoch 13/25
# 65/65 [==============================] - 483s 7s/step - loss: 0.4837 - accuracy: 0.7779 - val_loss: 0.4611 - val_accuracy: 0.7804
# Epoch 14/25
# 65/65 [==============================] - 515s 8s/step - loss: 0.4794 - accuracy: 0.7790 - val_loss: 0.4482 - val_accuracy: 0.7884
# Epoch 15/25
# 65/65 [==============================] - 511s 8s/step - loss: 0.4668 - accuracy: 0.7887 - val_loss: 0.4377 - val_accuracy: 0.8016
# Epoch 16/25
# 65/65 [==============================] - 507s 8s/step - loss: 0.4661 - accuracy: 0.7809 - val_loss: 0.4739 - val_accuracy: 0.7831
# Epoch 17/25
# 65/65 [==============================] - 585s 9s/step - loss: 0.4636 - accuracy: 0.7894 - val_loss: 0.4541 - val_accuracy: 0.8016
# Epoch 18/25
# 65/65 [==============================] - 682s 10s/step - loss: 0.4638 - accuracy: 0.7802 - val_loss: 0.4288 - val_accuracy: 0.7963
# Epoch 19/25
# 65/65 [==============================] - 704s 11s/step - loss: 0.4545 - accuracy: 0.7921 - val_loss: 0.4238 - val_accuracy: 0.8201
# Epoch 20/25
# 65/65 [==============================] - 642s 10s/step - loss: 0.4666 - accuracy: 0.7825 - val_loss: 0.4867 - val_accuracy: 0.7831
# Epoch 21/25
# 65/65 [==============================] - 656s 10s/step - loss: 0.4577 - accuracy: 0.7809 - val_loss: 0.4958 - val_accuracy: 0.7857
# Epoch 22/25
# 65/65 [==============================] - 504s 8s/step - loss: 0.4546 - accuracy: 0.7890 - val_loss: 0.4721 - val_accuracy: 0.7963

# %% [markdown]
# ## Save Model

# %%
model.save(f'outputs/{version}/brain_tumor_detect_model.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Model Performance

# %% [markdown]
# Model learning curve

# %%
losses = pd.DataFrame(model.history.history)

sns.set_style("darkgrid")
losses[['loss', 'val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png', bbox_inches='tight',
            dpi=150)
plt.show()

print("\n")
losses[['accuracy', 'val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png', bbox_inches='tight',
            dpi=150)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
from keras.models import load_model
model = load_model(f'outputs/{version}/brain_tumor_detect_model.h5')
# Out:
# 2024-01-02 16:58:13.272579: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Evaluate saved model on test set

# %%
evaluation = model.evaluate(test_set)
# Out:
# 2024-01-02 16:58:21.056454: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-01-02 16:58:24.942105: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 290017280 exceeds 10% of free system memory.
# 2024-01-02 16:58:26.348950: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 72504320 exceeds 10% of free system memory.
# 2024-01-02 16:58:26.920998: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 140175360 exceeds 10% of free system memory.
# 2024-01-02 16:58:28.368319: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 64225280 exceeds 10% of free system memory.
#  1/19 [>.............................] - ETA: 2:34 - loss: 0.3573 - accuracy: 0.8000
# 2024-01-02 16:58:30.194219: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 290017280 exceeds 10% of free system memory.
# 19/19 [==============================] - 88s 4s/step - loss: 0.4400 - accuracy: 0.7989

# %% [markdown]
# Save evaluation pickle

# %%
joblib.dump(value=evaluation,
            filename=f"outputs/{version}/evaluation.pkl")
# Out:
# ['outputs/v1/evaluation.pkl']

# %%
labels
# Out:
# ['mri-tumor', 'mri-non-tumor']

# %%
## Model Evaluation - Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix
pred = model.predict(test_set)
y_pred = np.concatenate(np.round(pred).astype(int))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       4 pred = model.predict(test_set)
#       5 y_pred = np.concatenate(np.round(pred).astype(int))
# ----> 7 cnf_matrix = confusion_matrix(y_test, y_pred)
#      10 print(cnf_matrix)
#      13 ## RMSE
#
# NameError: name 'y_test' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix
pred = model.predict(test_set)
y_pred = np.concatenate(np.round(pred).astype(int))
target_names = labels
confusion_matrix = confusion_matrix(test_set.classes, y_pred)
print(confusion_matrix)
plt.figure(figsize=(7, 6))
sns.heatmap(confusion_matrix,
            annot=True,
            fmt='g',
            cmap='BuPu',
            xticklabels=['Predicted mri-tumor', 'Predicted mri-non-tumor'],
            yticklabels=[' Actual mri-tumor', 'Actual mri-non-tumor'],)
plt.savefig(f'{file_path}/confusion_matrix.png', bbox_inches='tight', dpi=150)
print(classification_report(test_set.classes, y_pred, 
      target_names=target_names))
# Out:
# [[208 207]
#  [175 161]]
#                precision    recall  f1-score   support
#
#     mri-tumor       0.54      0.50      0.52       415
# mri-non-tumor       0.44      0.48      0.46       336
#
#      accuracy                           0.49       751
#     macro avg       0.49      0.49      0.49       751
#  weighted avg       0.50      0.49      0.49       751

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Load a random image as PIL

# %%
from tensorflow.keras.preprocessing import image
import os

pointer = 49
label = labels[0]

image_path = os.path.join(test_path, label, os.listdir(os.path.join(test_path, label))[pointer])

pil_image = image.load_img(image_path, target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (240, 240), Image mode: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240>

# %% [markdown]
# Convert image to array and prepare for prediciton

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 240, 240, 3)

# %% [markdown]
# Predict class probabilities

# %%
pred_proba = model.predict(my_image)[0, 0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class = target_map[pred_proba > 0.5]

if pred_class == target_map[0]:
    pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# 0.8548437
# mri-tumor
